# %% [markdown]
# # Mount com o Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Configuracao do Spark

# %%
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# Download Spark
# !wget -q https://dlcdn.apache.org/spark/spark-3.3.2/spark-3.3.2-bin-hadoop3.tgz
# Unzip the file
# !tar xf spark-3.3.2-bin-hadoop3.tgz

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = '/content/spark-3.3.2-bin-hadoop3'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages io.delta:delta-core_2.12:2.1.0 --conf spark.sql.extensions=io.delta.sql.DeltaSparkSessionExtension --conf spark.sql.catalog.spark_catalog=org.apache.spark.sql.delta.catalog.DeltaCatalog pyspark-shell'

# %%
# Install library for finding Spark
# !pip install -q findspark
# Import the libary
import findspark
# Initiate findspark
findspark.init()
# Check the location for Spark
findspark.find()
# Out:
# '/content/spark-3.3.2-bin-hadoop3'

# %%
def install_java():
  # !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null      #install openjdk
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable
  # !java -version       #check java version
install_java()
# Out:
# openjdk version "11.0.18" 2023-01-17
# OpenJDK Runtime Environment (build 11.0.18+10-post-Ubuntu-0ubuntu120.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.18+10-post-Ubuntu-0ubuntu120.04.1, mixed mode, sharing)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
spark = SparkSession.builder.appName('delta_session').getOrCreate()

# %%
# Bibliotecas pyspark
from pyspark.sql import SparkSession,SQLContext
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %% [markdown]
# # Define parameters

# %%
#entrada
path_pib =  f'/content/drive/MyDrive/Case_Mercado_Livre/PIB/API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_5358720.csv'
path_tax_juros =  f'/content/drive/MyDrive/Case_Mercado_Livre/Taxa de Juros Ativa/API_FR.INR.LEND_DS2_es_csv_v2_5381469.csv'
path_dados_socioeconomicos =  f'/content/drive/MyDrive/Case_Mercado_Livre/dados socioeconomicos/API_Download_DS2_en_csv_v2_5389446.csv'
path_nav_marketplace_arg =  f'/content/drive/MyDrive/Case_Mercado_Livre/navegacao_marketplaces.csv'
path_desempenho_ml_arg =  f'/content/drive/MyDrive/Case_Mercado_Livre/desempenho-ml-argentina-2022-03.csv'
path_desempenho_ml_br =  f'/content/drive/MyDrive/Case_Mercado_Livre/desempenho-ml-brasil-2022-03.csv'

# saida
path_dest_macroeconomicos = f'/content/drive/MyDrive/Case_Mercado_Livre/output/macroeconomicos'
path_dest_desempenho_ml = f'/content/drive/MyDrive/Case_Mercado_Livre/output/desempenho_ml'
path_dest_nav_marketplace_arg = f'/content/drive/MyDrive/Case_Mercado_Livre/output/nav_marketplace_arg'

# %% [markdown]
# # Carregamento das bases para dataframes

# %%
df_pib= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_pib)
df_tax_juros= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_tax_juros)
df_dados_socioeconomicos= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_dados_socioeconomicos)
df_nav_marketplace_arg= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_nav_marketplace_arg)
df_desempenho_ml_arg= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_desempenho_ml_arg)
df_desempenho_ml_br= spark.read.format("csv").option("delimiter", ",").option("header","true").option("encoding", "UTF-8").load(path_desempenho_ml_br)

# %% [markdown]
# # selecao de colunas de interesse

# %%
df_pib= df_pib.select("Country Name","Indicator Name","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021")
df_tax_juros= df_tax_juros.select("Country Name","Indicator Name","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021")
df_dados_socioeconomicos= df_dados_socioeconomicos.select("Country Name","Indicator Name","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021")
df_desempenho_ml_arg = df_desempenho_ml_arg.withColumn("pais",lit("Argentina"))
df_desempenho_ml_br = df_desempenho_ml_br.withColumn("pais",lit("Brasil"))

# %% [markdown]
# # Filtro das linhas de interesse

# %%
df_pib= df_pib.filter((col("Country Name") == 'Argentina')|(col("Country Name") == 'Brasil'))
df_tax_juros= df_tax_juros.filter((col("Country Name") == 'Argentina')|(col("Country Name") == 'Brasil'))
df_dados_socioeconomicos= df_dados_socioeconomicos.filter((col("Indicator Name") == 'Age dependency ratio (% of working-age population)')\
                                                                  |(col("Indicator Name") == 'Unemployment, total (% of total labor force) (modeled ILO estimate)')\
                                                                  |(col("Indicator Name") == 'GDP per capita (current US$)')\
                                                                  |(col("Indicator Name") == 'Inflation, GDP deflator: linked series (annual %)')\
                                                                  |(col("Indicator Name") == 'Final consumption expenditure (current US$)')\
                                                                  |(col("Indicator Name") == 'Government expenditure per student, secondary (% of GDP per capita)')\
                                                                  |(col("Indicator Name") == 'Mobile cellular subscriptions')\
                                                                  |(col("Indicator Name") == 'Individuals using the Internet (% of population)')\
                                                                  |(col("Indicator Name") == 'New businesses registered (number)')\
                                                                  |(col("Indicator Name") == 'Population, total'))

# %% [markdown]
# # Unpivot dos dados

# %%
# PIB
df_pib_pivot = df_pib.withColumn("dados",array(array(col("2011"),lit('2011')),array(col("2012"),lit('2012')),array(col("2013"),lit('2013')),array(col("2014"),lit('2014')),array(col("2015"),lit('2015'))\
                                               ,array(col("2016"),lit('2016')),array(col("2017"),lit('2017')),array(col("2018"),lit('2018')),array(col("2019"),lit('2019')),array(col("2020"),lit('2020'))\
                                               ,array(col("2021"),lit('2021'))))

df_pib_pivot = df_pib_pivot.withColumn("dados",explode("dados"))
df_pib_exp = df_pib_pivot.withColumn("ano", df_pib_pivot["dados"].getItem(1)).withColumn("valor", df_pib_pivot["dados"].getItem(0))
df_pib_final = df_pib_exp.select("Country Name","Indicator Name","ano","valor")

# Taxa de Juros
df_tax_juros_pivot = df_tax_juros.withColumn("dados",array(array(col("2011"),lit('2011')),array(col("2012"),lit('2012')),array(col("2013"),lit('2013')),array(col("2014"),lit('2014')),array(col("2015"),lit('2015'))\
                                               ,array(col("2016"),lit('2016')),array(col("2017"),lit('2017')),array(col("2018"),lit('2018')),array(col("2019"),lit('2019')),array(col("2020"),lit('2020'))\
                                               ,array(col("2021"),lit('2021'))))

df_tax_juros_pivot = df_tax_juros_pivot.withColumn("dados",explode("dados"))
df_tax_juros_exp = df_tax_juros_pivot.withColumn("ano", df_tax_juros_pivot["dados"].getItem(1)).withColumn("valor", df_tax_juros_pivot["dados"].getItem(0))
df_tax_juros_final = df_tax_juros_exp.select("Country Name","Indicator Name","ano","valor")

# dados_socioeconomicos
df_dados_socioeconomicos_pivot = df_dados_socioeconomicos.withColumn("dados",array(array(col("2011"),lit('2011')),array(col("2012"),lit('2012')),array(col("2013"),lit('2013')),array(col("2014"),lit('2014')),array(col("2015"),lit('2015'))\
                                               ,array(col("2016"),lit('2016')),array(col("2017"),lit('2017')),array(col("2018"),lit('2018')),array(col("2019"),lit('2019')),array(col("2020"),lit('2020'))\
                                               ,array(col("2021"),lit('2021'))))

df_dados_socioeconomicos_pivot = df_dados_socioeconomicos_pivot.withColumn("dados",explode("dados"))
df_dados_socioeconomicos_exp = df_dados_socioeconomicos_pivot.withColumn("ano", df_dados_socioeconomicos_pivot["dados"].getItem(1)).withColumn("valor", df_dados_socioeconomicos_pivot["dados"].getItem(0))
df_dados_socioeconomicos_final = df_dados_socioeconomicos_exp.select("Country Name","Indicator Name","ano","valor")

# %% [markdown]
# # Uniao dos dados

# %%
df_macroeconomicos = df_pib_final.union(df_tax_juros_final)\
                                  .union(df_dados_socioeconomicos_final)

# %%
df_desempenho_ml = df_desempenho_ml_arg.union(df_desempenho_ml_br)

# %% [markdown]
# # calculo da porcentagem da populacao

# %%
df_macroeconomicos = df_macroeconomicos.withColumn("valor",when(col("indicator_name").contains("%"),col("valor")/10000000).otherwise(col("value")))
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-52-9b03b4783513> in <cell line: 1>()
# ----> 1 df_macroeconomicos = df_macroeconomicos.withColumn("valor",when(col("indicator_name").contains("%"),col("valor")/10000000).otherwise(col("value")))
#
# /content/spark-3.3.2-bin-hadoop3/python/pyspark/sql/dataframe.py in withColumn(self, colName, col)
#    3034         if not isinstance(col, Column):
#    3035             raise TypeError("col should be Column")
# -> 3036         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#    3037
#    3038     def withColumnRenamed(self, existing: str, new: str) -> "DataFrame":
#
# /content/spark-3.3.2-bin-hadoop3/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# /content/spark-3.3.2-bin-hadoop3/python/pyspark/sql/utils.py in deco(*a, **kw)
#     194                 # Hide where the exception came from that shows a non-Pythonic
#     195                 # JVM exception message.
# --> 196                 raise converted from None
#     197             else:
#     198                 raise
#
# AnalysisException: Column 'value' does not exist. Did you mean one of the following? [valor, ano, country_name, indicator_name];
# 'Project [country_name#1538, indicator_name#1543, ano#1343, CASE WHEN Contains(indicator_name#1543, %) THEN (cast(valor#1359 as double) / cast(10000000 as double)) ELSE 'value END AS valor#1598]
# +- Project [country_name#1538, Indicator Name#19 AS indicator_name#1543, ano#1343, valor#1359]
#    +- Project [Country Name#17 AS country_name#1538, Indicator Name#19, ano#1343, valor#1359]
#       +- Union false, false
#          :- Project [Country Name#17, Indicator Name#19, dados#1328[1] AS ano#1343, dados#1328[0] AS valor#1359]
#          :  +- Generate explode(dados#1312), false, [dados#1328]
#          :     +- Project [Country Name#17, Indicator Name#19, 2011#72, 2012#73, 2013#74, 2014#75, 2015#76, 2016#77, 2017#78, 2018#79, 2019#80, 2020#81, 2021#82, array(array(2011#72, 2011), array(2012#73, 2012), array(2013#74, 2013), array(2014#75, 2014), array(2015#76, 2015), array(2016#77, 2016), array(2017#78, 2017), array(2018#79, 2018), array(2019#80, 2019), array(2020#81, 2020), array(2021#82, 2021)) AS dados#1312]
#          :        +- Filter ((Country Name#17 = Argentina) OR (Country Name#17 = Brasil))
#          :           +- Project [Country Name#17, Indicator Name#19, 2011#72, 2012#73, 2013#74, 2014#75, 2015#76, 2016#77, 2017#78, 2018#79, 2019#80, 2020#81, 2021#82]
#          :              +- Filter ((Country Name#17 = Argentina) OR (Country Name#17 = Brasil))
#          :                 +- Project [Country Name#17, Indicator Name#19, 2011#72, 2012#73, 2013#74, 2014#75, 2015#76, 2016#77, 2017#78, 2018#79, 2019#80, 2020#81, 2021#82]
#          :                    +- Filter ((Country Name#17 = Argentina) OR (Country Name#17 = Brasil))
#          :                       +- Project [Country Name#17, Indicator Name#19, 2011#72, 2012#73, 2013#74, 2014#75, 2015#76, 2016#77, 2017#78, 2018#79, 2019#80, 2020#81, 2021#82]
#          :                          +- Relation [Country Name#17,Country Code#18,Indicator Name#19,Indicator Code#20,1960#21,1961#22,1962#23,1963#24,1964#25,1965#26,1966#27,1967#28,1968#29,1969#30,1970#31,1971#32,1972#33,1973#34,1974#35,1975#36,1976#37,1977#38,1978#39,1979#40,... 43 more fields] csv
#          :- Project [Country Name#168, Indicator Name#170, dados#1396[1] AS ano#1411, dados#1396[0] AS valor#1427]
#          :  +- Generate explode(dados#1380), false, [dados#1396]
#          :     +- Project [Country Name#168, Indicator Name#170, 2011#223, 2012#224, 2013#225, 2014#226, 2015#227, 2016#228, 2017#229, 2018#230, 2019#231, 2020#232, 2021#233, array(array(2011#223, 2011), array(2012#224, 2012), array(2013#225, 2013), array(2014#226, 2014), array(2015#227, 2015), array(2016#228, 2016), array(2017#229, 2017), array(2018#230, 2018), array(2019#231, 2019), array(2020#232, 2020), array(2021#233, 2021)) AS dados#1380]
#          :        +- Filter ((Country Name#168 = Argentina) OR (Country Name#168 = Brasil))
#          :           +- Project [Country Name#168, Indicator Name#170, 2011#223, 2012#224, 2013#225, 2014#226, 2015#227, 2016#228, 2017#229, 2018#230, 2019#231, 2020#232, 2021#233]
#          :              +- Filter ((Country Name#168 = Argentina) OR (Country Name#168 = Brasil))
#          :                 +- Project [Country Name#168, Indicator Name#170, 2011#223, 2012#224, 2013#225, 2014#226, 2015#227, 2016#228, 2017#229, 2018#230, 2019#231, 2020#232, 2021#233]
#          :                    +- Filter ((Country Name#168 = Argentina) OR (Country Name#168 = Brasil))
#          :                       +- Project [Country Name#168, Indicator Name#170, 2011#223, 2012#224, 2013#225, 2014#226, 2015#227, 2016#228, 2017#229, 2018#230, 2019#231, 2020#232, 2021#233]
#          :                          +- Relation [Country Name#168,Country Code#169,Indicator Name#170,Indicator Code#171,1960#172,1961#173,1962#174,1963#175,1964#176,1965#177,1966#178,1967#179,1968#180,1969#181,1970#182,1971#183,1972#184,1973#185,1974#186,1975#187,1976#188,1977#189,1978#190,1979#191,... 43 more fields] csv
#          +- Project [Country Name#319, Indicator Name#321, dados#1464[1] AS ano#1479, dados#1464[0] AS valor#1495]
#             +- Generate explode(dados#1448), false, [dados#1464]
#                +- Project [Country Name#319, Indicator Name#321, 2011#374, 2012#375, 2013#376, 2014#377, 2015#378, 2016#379, 2017#380, 2018#381, 2019#382, 2020#383, 2021#384, array(array(2011#374, 2011), array(2012#375, 2012), array(2013#376, 2013), array(2014#377, 2014), array(2015#378, 2015), array(2016#379, 2016), array(2017#380, 2017), array(2018#381, 2018), array(2019#382, 2019), array(2020#383, 2020), array(2021#384, 2021)) AS dados#1448]
#                   +- Filter ((((((((((Indicator Name#321 = Age dependency ratio (% of working-age population)) OR (Indicator Name#321 = Unemployment, total (% of total labor force) (modeled ILO estimate))) OR (Indicator Name#321 = GDP per capita (current US$))) OR (Indicator Name#321 = Inflation, GDP deflator: linked series (annual %))) OR (Indicator Name#321 = Final consumption expenditure (current US$))) OR (Indicator Name#321 = Government expenditure per student, secondary (% of GDP per capita))) OR (Indicator Name#321 = Mobile cellular subscriptions)) OR (Indicator Name#321 = Individuals using the Internet (% of population))) OR (Indicator Name#321 = New businesses registered (number))) OR (Indicator Name#321 = Population, total))
#                      +- Project [Country Name#319, Indicator Name#321, 2011#374, 2012#375, 2013#376, 2014#377, 2015#378, 2016#379, 2017#380, 2018#381, 2019#382, 2020#383, 2021#384]
#                         +- Filter ((((((((((Indicator Name#321 = Age dependency ratio (% of working-age population)) OR (Indicator Name#321 = Unemployment, total (% of total labor force) (modeled ILO estimate))) OR (Indicator Name#321 = GDP per capita (current US$))) OR (Indicator Name#321 = Inflation, GDP deflator: linked series (annual %))) OR (Indicator Name#321 = Final consumption expenditure (current US$))) OR (Indicator Name#321 = Government expenditure per student, secondary (% of GDP per capita))) OR (Indicator Name#321 = Mobile cellular subscriptions)) OR (Indicator Name#321 = Individuals using the Internet (% of population))) OR (Indicator Name#321 = New businesses registered (number))) OR (Indicator Name#321 = Population, total))
#                            +- Project [Country Name#319, Indicator Name#321, 2011#374, 2012#375, 2013#376, 2014#377, 2015#378, 2016#379, 2017#380, 2018#381, 2019#382, 2020#383, 2021#384]
#                               +- Filter ((((((((((Indicator Name#321 = Age dependency ratio (% of working-age population)) OR (Indicator Name#321 = Unemployment, total (% of total labor force) (modeled ILO estimate))) OR (Indicator Name#321 = GDP per capita (current US$))) OR (Indicator Name#321 = Inflation, GDP deflator: linked series (annual %))) OR (Indicator Name#321 = Final consumption expenditure (current US$))) OR (Indicator Name#321 = Government expenditure per student, secondary (% of GDP per capita))) OR (Indicator Name#321 = Mobile cellular subscriptions)) OR (Indicator Name#321 = Individuals using the Internet (% of population))) OR (Indicator Name#321 = New businesses registered (number))) OR (Indicator Name#321 = Population, total))
#                                  +- Project [Country Name#319, Indicator Name#321, 2011#374, 2012#375, 2013#376, 2014#377, 2015#378, 2016#379, 2017#380, 2018#381, 2019#382, 2020#383, 2021#384]
#                                     +- Relation [Country Name#319,Country Code#320,Indicator Name#321,Indicator Code#322,1960#323,1961#324,1962#325,1963#326,1964#327,1965#328,1966#329,1967#330,1968#331,1969#332,1970#333,1971#334,1972#335,1973#336,1974#337,1975#338,1976#339,1977#340,1978#341,1979#342,... 43 more fields] csv

# %% [markdown]
# # removendo registros em branco

# %%
df_nav_marketplace_arg = df_nav_marketplace_arg.dropna()

# %% [markdown]
# # Renomeando Colunas

# %%
df_macroeconomicos = df_macroeconomicos.withColumnRenamed("Country Name","country_name")\
                                        .withColumnRenamed("Indicator Name","indicator_name")

# %% [markdown]
# # display dos bancos de dados para verificacao

# %%
df_pib.toPandas()
# Out:
#   Country Name                 Indicator Name              2011  \
# 0    Argentina  Crecimiento del PIB (% anual)  6.00395169280579
# 1       Brasil  Crecimiento del PIB (% anual)  3.97442307944702
#
#                2012              2013               2014               2015  \
# 0  -1.0264204544321  2.40532378079436  -2.51261532081394   2.73115982828944
# 1  1.92117598576537  3.00482266944432  0.503955740242247  -3.54576339269425
#
#                 2016              2017               2018               2019  \
# 0  -2.08032784377811  2.81850297775918  -2.61739646282038  -2.00086100285785
# 1  -3.27591690782192  1.32286905404399     1.783666761634   1.22077782360842
#
#                 2020              2021
# 0  -9.94323513446069  10.3982494646904
# 1  -3.87867633397198  4.61942162067312

# %%
df_pib_final.toPandas()
# Out:
#    Country Name                 Indicator Name   ano              valor
# 0     Argentina  Crecimiento del PIB (% anual)  2011   6.00395169280579
# 1     Argentina  Crecimiento del PIB (% anual)  2012   -1.0264204544321
# 2     Argentina  Crecimiento del PIB (% anual)  2013   2.40532378079436
# 3     Argentina  Crecimiento del PIB (% anual)  2014  -2.51261532081394
# 4     Argentina  Crecimiento del PIB (% anual)  2015   2.73115982828944
# 5     Argentina  Crecimiento del PIB (% anual)  2016  -2.08032784377811
# 6     Argentina  Crecimiento del PIB (% anual)  2017   2.81850297775918
# 7     Argentina  Crecimiento del PIB (% anual)  2018  -2.61739646282038
# 8     Argentina  Crecimiento del PIB (% anual)  2019  -2.00086100285785
# 9     Argentina  Crecimiento del PIB (% anual)  2020  -9.94323513446069
# 10    Argentina  Crecimiento del PIB (% anual)  2021   10.3982494646904
# 11       Brasil  Crecimiento del PIB (% anual)  2011   3.97442307944702
# 12       Brasil  Crecimiento del PIB (% anual)  2012   1.92117598576537
# 13       Brasil  Crecimiento del PIB (% anual)  2013   3.00482266944432
# 14       Brasil  Crecimiento del PIB (% anual)  2014  0.503955740242247
# 15       Brasil  Crecimiento del PIB (% anual)  2015  -3.54576339269425
# 16       Brasil  Crecimiento del PIB (% anual)  2016  -3.27591690782192
# 17       Brasil  Crecimiento del PIB (% anual)  2017   1.32286905404399
# 18       Brasil  Crecimiento del PIB (% anual)  2018     1.783666761634
# 19       Brasil  Crecimiento del PIB (% anual)  2019   1.22077782360842
# 20       Brasil  Crecimiento del PIB (% anual)  2020  -3.87867633397198
# 21       Brasil  Crecimiento del PIB (% anual)  2021   4.61942162067312

# %%
df_tax_juros.toPandas()
# Out:
#   Country Name              Indicator Name              2011  \
# 0    Argentina  Tasa de interés activa (%)           14.0875
# 1       Brasil  Tasa de interés activa (%)  43.8833333333333
#
#                2012              2013              2014              2015  \
# 0  14.0608333333333  17.1491666666667  24.0091666666667  24.9158333333333
# 1  36.6366666666667  27.3916666666667  32.0083333333333  43.9583333333333
#
#       2016              2017              2018              2019  \
# 0  31.2325  26.5808333333333  48.5166666666667  67.2541666666667
# 1     52.1  46.9166666666667  39.0833333333333            37.475
#
#                2020              2021
# 0           29.3875  35.5583333333333
# 1  29.0416666666667  30.0166666666667

# %%
df_tax_juros_final.toPandas()
# Out:
#    Country Name              Indicator Name   ano             valor
# 0     Argentina  Tasa de interés activa (%)  2011           14.0875
# 1     Argentina  Tasa de interés activa (%)  2012  14.0608333333333
# 2     Argentina  Tasa de interés activa (%)  2013  17.1491666666667
# 3     Argentina  Tasa de interés activa (%)  2014  24.0091666666667
# 4     Argentina  Tasa de interés activa (%)  2015  24.9158333333333
# 5     Argentina  Tasa de interés activa (%)  2016           31.2325
# 6     Argentina  Tasa de interés activa (%)  2017  26.5808333333333
# 7     Argentina  Tasa de interés activa (%)  2018  48.5166666666667
# 8     Argentina  Tasa de interés activa (%)  2019  67.2541666666667
# 9     Argentina  Tasa de interés activa (%)  2020           29.3875
# 10    Argentina  Tasa de interés activa (%)  2021  35.5583333333333
# 11       Brasil  Tasa de interés activa (%)  2011  43.8833333333333
# 12       Brasil  Tasa de interés activa (%)  2012  36.6366666666667
# 13       Brasil  Tasa de interés activa (%)  2013  27.3916666666667
# 14       Brasil  Tasa de interés activa (%)  2014  32.0083333333333
# 15       Brasil  Tasa de interés activa (%)  2015  43.9583333333333
# 16       Brasil  Tasa de interés activa (%)  2016              52.1
# 17       Brasil  Tasa de interés activa (%)  2017  46.9166666666667
# 18       Brasil  Tasa de interés activa (%)  2018  39.0833333333333
# 19       Brasil  Tasa de interés activa (%)  2019            37.475
# 20       Brasil  Tasa de interés activa (%)  2020  29.0416666666667
# 21       Brasil  Tasa de interés activa (%)  2021  30.0166666666667

# %%
df_dados_socioeconomicos.toPandas()
# Out:
#    Country Name                                     Indicator Name  \
# 0     Argentina                                  Population, total
# 1     Argentina  Government expenditure per student, secondary ...
# 2     Argentina  Age dependency ratio (% of working-age populat...
# 3     Argentina  Unemployment, total (% of total labor force) (...
# 4     Argentina                       GDP per capita (current US$)
# 5     Argentina  Inflation, GDP deflator: linked series (annual %)
# 6     Argentina        Final consumption expenditure (current US$)
# 7     Argentina   Individuals using the Internet (% of population)
# 8     Argentina                      Mobile cellular subscriptions
# 9     Argentina                 New businesses registered (number)
# 10       Brazil                                  Population, total
# 11       Brazil  Government expenditure per student, secondary ...
# 12       Brazil  Age dependency ratio (% of working-age populat...
# 13       Brazil  Unemployment, total (% of total labor force) (...
# 14       Brazil                       GDP per capita (current US$)
# 15       Brazil  Inflation, GDP deflator: linked series (annual %)
# 16       Brazil        Final consumption expenditure (current US$)
# 17       Brazil   Individuals using the Internet (% of population)
# 18       Brazil                      Mobile cellular subscriptions
# 19       Brazil                 New businesses registered (number)
#
#                 2011              2012              2013              2014  \
# 0           41261490          41733271          42202935          42669500
# 1           20.64525          20.75691          21.62494          21.31954
# 2   56.3546668780625  56.1922783212828  56.0868723571096  55.9732762411572
# 3   7.17999982833862  7.21999979019165  7.09999990463257  7.26999998092651
# 4   12848.8641969705   13082.664325572  13080.2547323367  12334.7982453893
# 5   23.7034721839593  22.3148806733049  23.9487984162746  40.2829716315506
# 6   423649649448.919  445242277160.302  457042608919.298   433334542562.24
# 7                 51              55.8              59.9              64.7
# 8           60722729          64327647          67361515          61234216
# 9               5828              4928              5406              4699
# 10         198185302         199977707         201721767         203459650
# 11           21.8504          19.66737          20.57305          20.56801
# 12  45.6653351926371  45.0350586274935  44.4544779067254  43.9999550715968
# 13  7.57999992370605              7.25  7.07000017166138  6.76000022888184
# 14  13200.7850823986  12327.3174365132  12258.5031683848  12071.1582132348
# 15   8.3185922188201  7.94312694206415  7.50456453204858  7.84670974349484
# 16   2065310855571.5  1970720392862.63  1993273502620.47  2016692732596.68
# 17             45.69             48.56             51.04       54.55100188
# 18         234357507         248323703         271099799         280728796
# 19            355326            311644            304549            267225
#
#                 2015              2016              2017              2018  \
# 0           43131966          43590368          44044811          44494502
# 1           22.87436          21.59171           20.6226              None
# 2   55.8644592427226  55.7543621214315  55.6112391046053  55.4071736223346
# 3   7.52400016784668  8.10900020599365  8.35000038146973  9.22000026702881
# 4    13789.060424772  12790.2424732447   14613.041824658  11795.1593866287
# 5   26.5799916024707  41.1193799882279  26.0063792819079  42.0336689575031
# 6   499614480942.488  464849978689.813  543457307147.989  447541502349.172
# 7        68.04306411       70.96898082       74.29490687              77.7
# 8           61842011          63719805          61897379          58598041
# 9               4958              5885              6209              5667
# 10         205188205         206859578         208504960         210166592
# 11          21.52655              None              None              None
# 12  43.6863997948724  43.4173920476343  43.2170324672364  43.1545346628714
# 13   8.5600004196167  11.7399997711182  12.9300003051758   12.460000038147
# 14  8783.22598387817  8680.76879182018  9896.68478335903  9121.08340257783
# 15  7.56617501293937  8.10360435702502  3.67138451288938  4.49353433164119
# 16  1509203462532.69  1519715006129.52  1746887572914.71  1620034210958.45
# 17       58.32795173       60.87254007       67.47128452       70.43428254
# 18         257814274         244067356         221269215         209410048
# 19            245830            226570            235300            253902
#
#                 2019              2020              2021
# 0           44938712          45376763          45808747
# 1               None              None              None
# 2   55.1353088624017  54.7600781645305  54.2701483886344
# 3   9.84000015258789   11.460000038147  8.73999977111816
# 4    9963.6725062053  8496.42414176374  10636.1201956183
# 5   49.1955790619497  40.0768830276961  54.1524119312346
# 6   369714687751.698  311065684471.896  373885266948.238
# 7               79.9              85.5       87.14829302
# 8           56352947          54763900          59065827
# 9               None              None              None
# 10         211782878         213196304         214326223
# 11              None              None              None
# 12  43.1445286839476  43.1137792522721  43.1060097297109
# 13  12.0500001907349  13.9300003051758  13.3400001525879
# 14  8845.25911841876  6794.48915877166  7507.16097080234
# 15  4.22425886990692  5.14022239700186  11.0963704321972
# 16  1594674103080.24  1207660007759.16  1288179862802.17
# 17       73.91244005       81.34269353              None
# 18         202009209         205834781         219660524
# 19            291392            405049              None

# %%
df_dados_socioeconomicos_final.toPandas()
# Out:
#     Country Name                      Indicator Name   ano     valor
# 0      Argentina                   Population, total  2011  41261490
# 1      Argentina                   Population, total  2012  41733271
# 2      Argentina                   Population, total  2013  42202935
# 3      Argentina                   Population, total  2014  42669500
# 4      Argentina                   Population, total  2015  43131966
# ..           ...                                 ...   ...       ...
# 215       Brazil  New businesses registered (number)  2017    235300
# 216       Brazil  New businesses registered (number)  2018    253902
# 217       Brazil  New businesses registered (number)  2019    291392
# 218       Brazil  New businesses registered (number)  2020    405049
# 219       Brazil  New businesses registered (number)  2021      None
#
# [220 rows x 4 columns]

# %%
df_nav_marketplace_arg.toPandas()
# Out:
#       country                 site Traffic Share MoM traffic Change  \
# 0         EUA           amazon.com        13.91%              9.33%
# 1         EUA             ebay.com         4.32%             11.83%
# 2       Japan         amazon.co.jp         3.37%              7.07%
# 3       Japan        rakuten.co.jp         3.05%              9.03%
# 4         EUA             etsy.com         2.86%              8.64%
# 5      Brazil       aliexpress.com         2.75%             14.04%
# 6     Germany            amazon.de         2.65%              9.95%
# 7         EUA          walmart.com         2.27%             10.01%
# 8      Russia       wildberries.ru         2.16%             12.07%
# 9          UK         amazon.co.uk         2.15%             11.03%
# 10     Russia              ozon.ru         2.01%              9.53%
# 11      China           taobao.com         1.92%              7.08%
# 12      India            amazon.in         1.86%              9.95%
# 13      China        pinduoduo.com         1.54%             14.74%
# 14     Brazil  mercadolivre.com.br         1.46%             10.71%
# 15         UK           ebay.co.uk         1.45%             12.34%
# 16     Poland           allegro.pl         1.28%               9.4%
# 17      India         flipkart.com         1.07%             12.18%
# 18     Russia     market.yandex.ru         1.04%              7.64%
# 19      Italy            amazon.it         1.03%              9.44%
# 20     Brazil        amazon.com.br         1.02%             13.64%
# 21    Germany              ebay.de         1.00%             12.78%
# 22     Canada            amazon.ca         0.98%             11.11%
# 23     France            amazon.fr         0.98%              8.25%
# 24     Turkey         trendyol.com         0.97%             19.44%
# 25        EUA           target.com         0.96%              7.56%
# 26     Poland         shopee.co.id         0.94%             10.77%
# 27      China               jd.com         0.85%              4.13%
# 28      Spain            amazon.es         0.82%              6.94%
# 29  Argentina       mercadolibre.c         0.80%              3.35%
#
#    Country Rank Monthly Visits Unique Visitors Visit Duration  Pages  \
# 0           #13         2.359B          448.7M        0:07:09   9.11
# 1           #38         731.9M          189.2M        0:06:59   6.85
# 2           #54         571.4M          77.27M        0:06:44   7.64
# 3           #56         516.7M          70.40M        0:06:24   7.50
# 4           #59         484.2M          188.0M        0:05:46   6.39
# 5           #71         466.3M          168.9M        0:05:57   4.83
# 6           #57         448.8M          77.14M        0:07:02   9.31
# 7           #84         385.4M          139.3M        0:04:38   4.88
# 8           #68         365.6M          57.74M        0:11:51  12.34
# 9           #75         364.2M          73.19M        0:06:16   7.80
# 10          #72         341.0M          80.36M        0:07:55  10.28
# 11          #96         324.9M          62.96M        0:05:55   7.27
# 12          #85         314.8M          111.5M        0:05:07   7.29
# 13         #227         261.1M          152.8M        0:00:34   1.32
# 14         #108         248.0M          60.78M        0:07:54   7.27
# 15         #105         245.8M          43.52M        0:09:00   8.99
# 16         #113         217.2M          30.45M        0:10:01  10.52
# 17         #161         180.7M          68.35M        0:05:14   6.02
# 18         #134         177.0M          47.35M        0:05:40   8.84
# 19         #139         175.3M          35.04M        0:06:58   9.21
# 20         #179         173.1M          58.89M        0:04:01   5.81
# 21         #160         170.1M          35.29M        0:08:21   8.09
# 22         #148         166.8M          35.09M        0:05:55   9.28
# 23         #146         166.5M          39.03M        0:06:58   9.03
# 24         #182         164.9M          40.10M        0:07:54   6.32
# 25         #188         162.0M          74.61M        0:03:52   5.53
# 26         #212         159.0M          48.31M        0:06:47   5.09
# 27         #190         144.1M          50.14M        0:05:03   7.16
# 28         #194         138.2M          34.48M        0:06:19   8.20
# 29         #192         135.4M          27.09M        0:08:10   9.64
#
#    Bounce Rate
# 0       35.15%
# 1       37.51%
# 2       36.16%
# 3       38.09%
# 4       46.33%
# 5       40.14%
# 6       32.61%
# 7       52.75%
# 8       27.02%
# 9       36.15%
# 10      32.16%
# 11      34.77%
# 12      46.99%
# 13      92.15%
# 14      38.39%
# 15      30.06%
# 16      28.13%
# 17      49.32%
# 18      24.39%
# 19      31.57%
# 20      51.77%
# 21      30.40%
# 22      30.24%
# 23      33.58%
# 24      35.28%
# 25      46.54%
# 26      40.33%
# 27      27.92%
# 28      35.70%
# 29      30.97%

# %%
df_desempenho_ml_arg.toPandas()
# Out:
#                  variavel               subvariavel      valor
# 0                  device                mobile Web     51.43%
# 1                  device                   Desktop     48.57%
# 2              num visita                    oct/22  137900000
# 3              num visita                    Nov-22  136900000
# 4              num visita                    dec/22  143500000
# 5              num visita                    Jan-23  154600000
# 6              num visita                    Feb-23  131100000
# 7              num visita                    Mar-23  135400000
# 8                 country                 Argentina     94.06%
# 9                 country             United States      0.71%
# 10                country                     Chile      0.64%
# 11                country                    Brazil      0.63%
# 12                country                    Mexico      0.52%
# 13     Marketing Channels                    direto     45.08%
# 14     Marketing Channels            organic search     41.90%
# 15     Marketing Channels                    social      5.37%
# 16     Marketing Channels               paid search      4.11%
# 17     Marketing Channels               referencias      2.55%
# 18     Marketing Channels                   correio      0.93%
# 19     Marketing Channels       mostrar propagandas      0.07%
# 20             engagement            Monthly visits  135400000
# 21             engagement   Monthly unique visitors   27090000
# 22             engagement  Visits / Unique visitors       5.00
# 23             engagement            Visit duration     489.00
# 24             engagement           Pages per visit       9.64
# 25             engagement               Bounce rate     30.98%
# 26         Social Traffic                   Youtube     44.47%
# 27         Social Traffic                  Whatsapp     21.17%
# 28         Social Traffic                  Facebook     18.98%
# 29         Social Traffic                 Instagram      6.91%
# 30         Social Traffic                   Twitter      3.58%
# 31         Social Traffic                     Other      4.89%
# 32         Top publishers          outlook.live.com     20.99%
# 33         Top publishers                  poki.com     20.99%
# 34         Top publishers               youtube.com     16.96%
# 35         Top publishers                 twitch.tv     11.19%
# 36         Top publishers               infobae.com      4.84%
# 37     Display Ad Network            Google Display     77.74%
# 38     Display Ad Network          Amazon Ad System      9.79%
# 39     Display Ad Network               blogger.com      6.89%
# 40     Display Ad Network                    others      5.62%
# 41  Top Link Destinations          mercadolibre.com     55.53%
# 42  Top Link Destinations        mercadopago.com.ar     11.27%
# 43  Top Link Destinations              mlstatic.com      4.77%
# 44  Top Link Destinations              whatsapp.com      3.16%
# 45  Top Link Destinations           mercadolibre.cl      2.57%
# 46            Advertisers              Outgoing ads       1051

# %%
df_desempenho_ml_br.toPandas()
# Out:
#                  variavel               subvariavel      valor
# 0                  device                mobile Web     59.01%
# 1                  device                   Desktop     40.99%
# 2              num visita                    oct/22  234100000
# 3              num visita                    Nov-22  244100000
# 4              num visita                    dec/22  256700000
# 5              num visita                    Jan-23  261500000
# 6              num visita                    Feb-23   22400000
# 7              num visita                    Mar-23   24800000
# 8                 country                    Brazil     97.39%
# 9                 country             United States      0.70%
# 10                country                     China      0.66%
# 11                country                     India      0.12%
# 12                country                     Egypt      0.10%
# 13     Marketing Channels                    direto     37.08%
# 14     Marketing Channels            organic search     37.26%
# 15     Marketing Channels                    social      5.09%
# 16     Marketing Channels               paid search     17.93%
# 17     Marketing Channels               referencias      1.49%
# 18     Marketing Channels                   correio      0.91%
# 19     Marketing Channels       mostrar propagandas      0.24%
# 20             engagement            Monthly visits  248000000
# 21             engagement   Monthly unique visitors   60780000
# 22             engagement  Visits / Unique visitors       4.08
# 23             engagement            Visit duration     471.00
# 24             engagement           Pages per visit       7.27
# 25             engagement               Bounce rate     38.43%
# 26         Social Traffic                   Youtube     43.25%
# 27         Social Traffic                  Whatsapp     29.35%
# 28         Social Traffic                  Facebook     15.89%
# 29         Social Traffic                 Instagram      4.72%
# 30         Social Traffic                   Twitter      2.16%
# 31         Social Traffic                     Other      4.62%
# 32         Top publishers               youtube.com     33.87%
# 33         Top publishers                 globo.com      9.33%
# 34         Top publishers                google.com      7.37%
# 35         Top publishers           webstech.online      4.49%
# 36         Top publishers                uol.com.br      2.69%
# 37     Display Ad Network            Google Display     90.78%
# 38     Display Ad Network                    Criteo      4.34%
# 39     Display Ad Network                   Taboola      3.17%
# 40     Display Ad Network                    others      1.72%
# 41  Top Link Destinations          mercadolibre.com     65.16%
# 42  Top Link Destinations        mercadopago.com.ar      7.17%
# 43  Top Link Destinations              mlstatic.com      7.24%
# 44  Top Link Destinations                google.com      2.47%
# 45  Top Link Destinations              starplus.com      2.11%
# 46            Advertisers              Outgoing ads     124000

# %%
df_macroeconomicos.toPandas()
# Out:
#     country_name                      indicator_name   ano              valor
# 0      Argentina       Crecimiento del PIB (% anual)  2011   6.00395169280579
# 1      Argentina       Crecimiento del PIB (% anual)  2012   -1.0264204544321
# 2      Argentina       Crecimiento del PIB (% anual)  2013   2.40532378079436
# 3      Argentina       Crecimiento del PIB (% anual)  2014  -2.51261532081394
# 4      Argentina       Crecimiento del PIB (% anual)  2015   2.73115982828944
# ..           ...                                 ...   ...                ...
# 259       Brazil  New businesses registered (number)  2017             235300
# 260       Brazil  New businesses registered (number)  2018             253902
# 261       Brazil  New businesses registered (number)  2019             291392
# 262       Brazil  New businesses registered (number)  2020             405049
# 263       Brazil  New businesses registered (number)  2021               None
#
# [264 rows x 4 columns]

# %%
df_desempenho_ml.toPandas()
# Out:
#                  variavel         subvariavel      valor       pais
# 0                  device          mobile Web     51.43%  Argentina
# 1                  device             Desktop     48.57%  Argentina
# 2              num visita              oct/22  137900000  Argentina
# 3              num visita              Nov-22  136900000  Argentina
# 4              num visita              dec/22  143500000  Argentina
# ..                    ...                 ...        ...        ...
# 89  Top Link Destinations  mercadopago.com.ar      7.17%     Brasil
# 90  Top Link Destinations        mlstatic.com      7.24%     Brasil
# 91  Top Link Destinations          google.com      2.47%     Brasil
# 92  Top Link Destinations        starplus.com      2.11%     Brasil
# 93            Advertisers        Outgoing ads     124000     Brasil
#
# [94 rows x 4 columns]

# %% [markdown]
# # Escrevendo os dataframes de saida

# %%
df_macroeconomicos\
.coalesce(1)\
.write\
.format("csv")\
.mode("overwrite")\
.save(path_dest_macroeconomicos)

# %%
df_desempenho_ml\
.coalesce(1)\
.write\
.format("csv")\
.mode("overwrite")\
.save(path_dest_desempenho_ml)

# %%
df_nav_marketplace_arg\
.coalesce(1)\
.write\
.format("csv")\
.mode("overwrite")\
.save(path_dest_nav_marketplace_arg)
